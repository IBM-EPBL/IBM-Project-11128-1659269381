# %%
import pandas as pd
import numpy as np
import sklearn as sk

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data = pd.read_csv("/content/drive/MyDrive/Churn_Modelling.csv")

# %%
data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
data.isnull().sum() #handling missing values
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
#encoding
from sklearn.preprocessing import LabelEncoder

# %%
le= LabelEncoder()

# %%
data['CreditScore']= le.fit_transform(data['CreditScore'])#catagorial to numerical

# %%
data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          228    France  Female   42
# 1          2    15647311      Hill          217     Spain  Female   41
# 2          3    15619304      Onio          111    France  Female   42
# 3          4    15701354      Boni          308    France  Female   39
# 4          5    15737888  Mitchell          459     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
y= data['EstimatedSalary']
x=data.drop(columns=['EstimatedSalary'],axis=1)

# %%
from sklearn.preprocessing import StandardScaler

# %%
names= x.columns

# %%
scaler=StandardScaler()

# %%
x
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          228    France  Female   42
# 1             2    15647311       Hill          217     Spain  Female   41
# 2             3    15619304       Onio          111    France  Female   42
# 3             4    15701354       Boni          308    France  Female   39
# 4             5    15737888   Mitchell          459     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          380    France    Male   39
# 9996       9997    15569892  Johnstone          125    France    Male   35
# 9997       9998    15584532        Liu          318    France  Female   36
# 9998       9999    15682355  Sabbatini          381   Germany    Male   42
# 9999      10000    15628319     Walker          401    France  Female   28
#
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
x_train
# Out:
#       RowNumber  CustomerId     Surname  CreditScore Geography  Gender  Age  \
# 3840       3841    15662884      Naylor          348   Germany    Male   58
# 567         568    15689614        Teng          296     Spain  Female   63
# 6524       6525    15743293      Waters          260   Germany  Female   35
# 9851       9852    15792077  Degtyaryov          280   Germany    Male   28
# 4256       4257    15578462         Hs?          205     Spain  Female   76
# ...         ...         ...         ...          ...       ...     ...  ...
# 5967       5968    15797919        Ting          382     Spain    Male   37
# 2413       2414    15604073        Bibi          424   Germany  Female   25
# 4343       4344    15654577    Alexeeva          158   Germany    Male   54
# 9383       9384    15739997       Capon          325    France  Female   23
# 1762       1763    15815660       Mazzi          367    France  Female   34
#
# ...

# %%
x_test
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography  Gender  Age  \
# 3575       3576    15625151          Wan          249    France  Female   66
# 6776       6777    15800583  Chukwuemeka          230     Spain  Female   43
# 3700       3701    15747345  Bergamaschi          287    France  Female   22
# 4968       4969    15572158    Blackburn          213     Spain    Male   41
# 2626       2627    15574324     Genovese          177   Germany  Female   29
# ...         ...         ...          ...          ...       ...     ...  ...
# 6525       6526    15598157    Onyeorulu          337    France    Male   34
# 6674       6675    15759034     Li Fonti          263    France    Male   36
# 7251       7252    15746995        Greco          333   Germany    Male   31
# 3569       3570    15761670       Morley          304    France  Female   50
# 5938       5939    15679668          Yao          459     Spain    Male   38
#
# ...

# %%
y_test
# Out:
# 3575    184636.05
# 6776    102806.60
# 3700    195424.01
# 4968     11819.84
# 2626    104617.99
#           ...
# 6525     88680.65
# 6674     12873.39
# 7251     12920.43
# 3569    126381.60
# 5938    162087.82
# Name: EstimatedSalary, Length: 2000, dtype: float64

# %%
y_train
# Out:
# 3840    160122.66
# 567      37938.74
# 6524     29583.48
# 9851    125422.66
# 4256     13455.43
#           ...
# 5967    178268.36
# 2413    136071.05
# 4343      2619.64
# 9383    185900.88
# 1762     60728.89
# Name: EstimatedSalary, Length: 8000, dtype: float64

# %%
x.describe #univariate
# Out:
# <bound method NDFrame.describe of       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          228    France  Female   42
# 1             2    15647311       Hill          217     Spain  Female   41
# 2             3    15619304       Onio          111    France  Female   42
# 3             4    15701354       Boni          308    France  Female   39
# 4             5    15737888   Mitchell          459     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          380    France    Male   39
# 9996       9997    15569892  Johnstone          125    France    Male   35
# 9997       9998    15584532        Liu          318    France  Female   36
# 9998       9999    15682355  Sabbatini          381   Germany    Male   42
# 9999      10000    15628319     Walker          401    France  Female   28
#
# ...

# %%
import matplotlib.pyplot as plt #bivariate

# %%
x=x.head(10)
x

# %%
plt.scatter(x.Age, x.Balance)
plt.title('Age vs Balance')
plt.xlabel('Age')
plt.ylabel('Balance')
# Out:
# Text(0, 0.5, 'Balance')
